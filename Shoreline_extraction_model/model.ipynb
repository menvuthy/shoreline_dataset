# %% [markdown]
# <div class="markdown-google-sans">
#
# # **<font size="6">Automated Shoreline Extraction Model</font>**
# </div>
#
#
# *Developed by Men Vuthy*
#
# ---

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### **Getting started**
# </div>
#
# This model enables a rapid and simple shoreline extraction from Landsat and Sentinel-2 satellite imagery for shoreline erosion and accretion analysis.

# %% [markdown]
# *Mount Google Drive*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# *Set path to model directory by using cd + path*

# %% [markdown]
# *Authenticate Google Earth Engine*

# %%
# !earthengine authenticate
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=xa7A38SHyAO3vDm3zkzEK38w_43cqku3cLAefk-PM3U&tc=c1msw7JvlG93UlW3xj_mwmo30_Cd5qm3Dmw6B0f0Q3w&cc=yIcO8EkC6gJ8SF7jCqJeLmR0riSP_HxsWlTUZ7dZ98E
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AbUR2VNJbWZdt7nJMgZiI9CHv-RaIVOyp212CcyHl1vMKM4tsMF2raoWnpM
#
# Successfully saved authorization token.

# %% [markdown]
# *Install environment*

# %%
# !apt install libspatialindex-dev
# !pip install -r requirements.txt

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### **1. Download**
# </div>
#
# Open `parameters.py` file:
#
# - Set area of interest by generating geometry from [Google Earth Engine](https://code.earthengine.google.com)
# - Set the date range
#
# *Check `docs/generate-geometry.gif` to see the tutorial on how to generate geometry.*
#
# Execute the code below to:
#
# - Pre-process and download Sentinel-2 image from Google Earth Engine

# %%
# !python execute_1_download_satellite_image.py
# Out:
# Downloading grid image: 1
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# Download is finished!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### **2. Extract shoreline**
# </div>
#
# Execute the code below to:
#
# - extract shorelines from all satellite images

# %%
# !python execute_2_shoreline_extraction.py
# Out:
# Extracting shoreline in 2019...
# Shoreline in 2019 is extracted.
# Shoreline extraction is finished!

# %% [markdown]
# Tips: Before continue to next step, please check and confirm if the extracted shoreline is acceptable. If not, feel free to manually modify it in QGIS, then reupload to drive.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### **3. Calculate growth and retreat**
# </div>
#
# Execute the code below to:
#
# - calculate shoreline growth and retreat

# %%
# !python execute_3_shoreline_analysis.py
# Out:
# Shoreline analysis is finished!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ### **4. Create maps of shorelines and shoreline changes**
# </div>
#
# Open `parameters.py` file:
#
# - Set the bin parameter for custom classification schemes
# - Create bins for total shoreline change and shoreline change rate per year
#
# Execute the code below to:
#
# - create static and interactive maps

# %%
# !python execute_4_mapping_shoreline.py

# %% [markdown]
# ---
